# %% [markdown]
# # 두근두근 믹싱볼!

# %%
import json
import pandas as pd 
import re
from collections import OrderedDict

# %%
with open('/opt/ml/mrc-level2-nlp-07/code/outputs/mixing_bowl/no1.json', 'r') as f:
    json_data1 = json.load(f)

# %%
with open('/opt/ml/mrc-level2-nlp-07/code/outputs/mixing_bowl/no2.json', 'r') as f:
    json_data2 = json.load(f)

# %%
for k in json_data1:
    check = 0
    try:
        net =[]
        for letter1 in json_data1[k]:
            for letter2 in json_data2[k]:
                if letter2 == letter1:
                    net.append(letter2)
                    break
        
        resultstring = ''.join(net)
        resultstring = re.sub('  ','',resultstring)
        
        json_data1[k] = resultstring
        print(resultstring) 

        json_data1[k] = json_data1[k] if len(json_data1[k])<len(json_data2[k]) else json_data2[k] 
    except:
        print(k)
# Out:
# '사만'
# '냉전 종식'
# '대통령인 빌헬름 미클라스'
# '뉴질랜드'
# '프랑스'
# '다리'
# '대의제도'
# ''
# '순조 11년(1811)'
# '고전도성 철'
# '리처드 말킨'
# ''
# '롭 포드'
# '노스햄프턴 교회'
# ' '
# '볼트'
# '국민'
# '‘자유’지에'
# '국방부 보고서'
# '입석대(立石臺)'
# '숙의 정씨'
# '국가인권위원회'
# '이탈리아'
# '망자'
# ' '
# '화흡'
# ' 전'
# '년'
# '신시내티대학교'
# '일등바위'
# ''
# '건늠선'
# ' '
# '가리는 '
# '13개'
# '경복사(景福寺)'
# '도시'
# '어머니'
# '저명한 상어 공격 전문가'
# ''
# '호어벨리샤'
# '목제'
# '시트로엥'
# '폴 베나세라프'
# '노르웨이'
# '1943년 7월 2일'
# '카에데 소이치로소치 카'
# '스털링 실리펀트'
# '2019년 8월 1일'
# "'강연옥'"
# '사비나'
# '미국 대통령 우드로 윌슨'
# '1584년(선조 17년)'
# ' 고등학교'
# '1916년'
# '삼국시대'
# '노포탑(露砲塔)'
# '()'
# ' 오이'
# '남미 자브로'
# '"연금"'
# '니 기븐'
# ''
# '근세'
# ''
# '시칠리아'
# '러더퍼드 B. 헤이스'
# '광고'
# '윌리엄 3세'
# '신라'
# '압'
# '위르겐 클린스만'
# '다이요'
# '필라델피아'
# '길거리 불한당'
# '스포츠 신문'
# '공유 필명'
# ''
# ''
# '비정상적으로 큰 송곳니'
# ' '
# '1933년'
# '제5중대장 김상흥 대위'
# ''
# ''
# '9월 16일 오후'
# '콘라트 2세'
# '예루살렘 성전'
# '호해'
# '아우구스투스 시대'
# '학업에 집중하기 위해'
# '하난야'
# '블라인드 테스트'
# '덩치 큰 어른'
# '성자정'
# '오코 카무'
# '노화욱'
# '도시구'
# ' 이 아'
# '안드레아스'
# '1991년'
# '시나위 대금'
# ' '
# '네스토리우스'
# '믈라카 술탄국'
# '“가상 연좌시위'
# '기원전 11년'
# '미국 긴축정책'
# '노예를 해방'
# '1995년'
# '쉴드 빔'
# '1802년'
# '보안'
# ' 사'
# '밀'
# '신라 경문왕'
# '큰곰자리 운동성군'
# '1720년'
# '모겐소'
# '디지털 영상'
# '《후한서》'
# '남자의 시체'
# '케빈 G. 린치'
# '난씨'
# '스카만드로스 강'
# '볼바라'
# '연합국'
# '이태웅'
# '호메이니'
# '상업 분야'
# '도요토미 히데요시'
# '스윙'
# '고려 말'
# '구충제 및 변비'
# "'죄를 범한 자'"
# '마리아 팔코네티'
# '쿠페'
# ' '
# '166년'
# '평균비용'
# 'HA1 도메인의 18번 코돈'
# 'SI'
# '무로마치 막부'
# '이승만'
# '약물'
# '강 노인'
# '미켈란젤로'
# '기암절벽'
# '국가안보상 필요할 경우'
# '성경의 요한 계시록'
# ''
# '교황'
# '통인 주기'
# '미국'
# '대막리지 연개소문'
# ''
# ''
# '12,000명'
# '오스마르'
# '고천제'
# '파시즘'
# ' 선 센리 선'
# '웅기탁'
# ''
# '신춘문예공모전'
# '1919년 10월 1일'
# '17세기'
# '다케다 한시(武田範之)'
# '뉴 허라이즌스 호'
# '모자'
# '여름철'
# '세르비아군'
# '내장 지방'
# '금융위원회'
# '에베소'
# '티탄즈'
# '3차원'
# '아루에'
# '1887년'
# '레이프 세거스탐'
# '사법부'
# '91 cm 구경의 굴절망원경'
# '5월 8일'
# '미술과'
# '영국'
# '후군'
# '고문'
# '엘디아'
# '트루먼의 아빠'
# 'Lea et al (1987)'
# '1530년'
# '자기장'
# '자자 빙크스'
# '일독일'
# '이라크'
# '191년'
# '1862년'
# '블랙홀'
# '80~90%'
# '백제금동대향로'
# '자유송환'
# ' '
# '유성생식'
# '마르크 오버르마르스'
# '1876년'
# '데이 페소'
# '소비에트 연방'
# '유교문화'
# '천공'
# '신성 로마 제국'
# '자동차 폐기장'
# '황금 황소상을 숭배하는 것'
# ''
# '이회창'
# '쿠니스'
# ' '
# '3년'
# '히틀러의 외투'
# '건강증서'
# '쿠파'
# '베를린'
# "'비공식 굿즈'"
# '합작 5원칙'
# ''
# '리FC'
# '1'
# '주선회'
# '정규 공간'
# '하미드 카르자이'
# '예시 아티드랑 텔렘당'
# '풍력이나 조력 발전 등 대체 에너지의 개발'
# '양극화'
# '자인단오-한장군 놀이'
# '베니토 무솔리니'
# '외교부 장관'
# '제작자 Chris Avellone'
# ''
# '역'
# '광주지방검찰청 순천지청'
# '실존주의'
# '종신형'
# '포토맥군'
# 'P 시리즈'
# ''
# '따끄옥루앗'
# ' 의 '
# '유럽의 서부 전선'
# '다.'
# '긴급 구호 건설 법령'
# ''
# '고려시대'
# '후장식 대포'
# '리비스'
# '감각기에'
# ' 다'
# '루피'
# '<의 >'
# '초등학교 교원'
# '정원 초과'
# '4점'
# '아칸바로'
# ''
# '키릴 문자'
# '감옥'
# '리을설(李乙雪, 1921-2015)'
# '당태종'
# '팔레스타인'
# '피오렐로 라과디아'
# '21년 월'
# '손가락'
# '리포스'
# "'농지'"
# '에'
# '유대인'
# '톰 디마르코'
# '마에노 료타쿠'
# '1988년'
# '플랑베르주'
# '조카 윤보선 '
# ''
# '일본국헌법'
# '글래스고 대학교'
# ''
# '제'
# '간석기(마제석기)'
# '아테네'
# '문장원'
# '오키나와어'
# '《작가의 일기》'
# '국립중앙박물관'
# '인'
# '파비아'
# '8명'
# 'API'
# '85번'
# ''
# '코네티컷 소년원'
# '15개'
# ''
# '1954년'
# ''
# '유대인'
# ' 다섯 가지 기쁨'
# '좌일선의 제1대대'
# ''
# '코드가 변조되거나 손상되지 않음'
# '1875년'
# '1922년'
# '루디 라모스'
# '금산전투'
# '지하 층'
# '사사'
# '찰스 2세'
# '마리 알렌'
# '매일 저녁'
# '요새'
# '1994'
# ''
# '안티트롬빈'
# '차가운 점액'
# '수영공원'
# ' '
# ''
# '5개'
# '인민의용군'
# '전라남도 지역'
# '일본 가도카와 쇼텐'
# '<<종횡무진 한국경제>>'
# '19년'
# '2세 황제 호해'
# '1773년'
# '사실주의'
# '르네상스 양식'
# 'Delay 1968'
# '5년'
# '하후상'
# '스톤페리어'
# '노동력부족'
# '언카스(또는 다운카스, Uncas)'
# '1번 ~ 9번'
# '법무성이'
# '일리노이주'
# '정통 칼리파'
# '경추'
# '오스트리아군'
# '이'
# '말'
# '스렝이'
# '16세기'
# '2월 혁명'
# '소프트웨어 엔지니어링'
# '경시청 수사1과'
# '식후 졸림증'
# '재산권 박탈'
# ''
# ''
# '갈리아인'
# '부산시'
# '"문학 혁명"'
# '줄기군 절지동물'
# '4막 3장이'
# '오스트리아-헝가리 제국 시대'
# '1935년'
# '시구르드'
# '금강산 보광암'
# '새누리당'
# '12척'
# '김 대령'
# '오티스 소프'
# '상서좌복야(尙書左僕射)'
# '극단적인 자전축 경사'
# '불투명하고 착색된 광물'
# ''
# ''
# '폭동'
# '1671년'
# '《소우기》'
# '하리수'
# ' '
# '시캉브르'
# '프랑스'
# '급진파 파시스트'
# '공수부대'
# '한스 칼 폰 빈터펠트 장군'
# 'CP0의 요원'
# '무대신'
# '라위스달'
# '삼흥'
# '"바라아"'
# '1945년'
# '칸'
# '미국'
# '「소방공무원법」'
# ''
# '위험한 물질'
# ' '
# '리 컬른'
# '송'
# '이스라엘'
# '레온 트로츠키'
# '태황제'
# '조선 후기'
# '테코아쿠'
# '고교시절'
# '<밤으로의 긴 여행>'
# ' 에'
# ' 정보 통달에 이를 때'
# ' '
# '1922년'
# '여성 금주 동맹'
# ''
# '오스트리아'
# '멕시코만류'
# '181년'
# '프랭클린 D. 루스벨트'
# '베다의 권위를 인정하는 가의 여부'
# '서재필'
# '2008년'
# '붉은 구슬'
# ''
# '인'
# '가족의 화합'
# '200만 달러'
# '남자아이 빈을 데려다 양자로 삼'
# '박근혜 대통령'
# '스'
# '황소'
# '260억 개'
# '헝가리'
# '퀸투스 루타티우스 카툴루스'
# '젊은이들'
# '제임스 패닌 대령'
# '내각회의'
# '드주드주아나의 동굴'
# '《나뭇잎의 집》'
# '한 번'
# '"하비 로우마이어"'
# '초음파 가습기'
# '강세황'
# '토우야'
# '위장'
# '오미이마즈 역'
# '전라북도 전주'
# '플라티니'
# '에에'
# '슈베르트'
# '목포터미널 인근 도심'
# '가즈사 부수의 난'
# '연청권'
# '중심지 이동설'
# '가속화 분류기'
# '1989년'
# '플로이드가 말을 하고 있으니 괜찮'
# '2009년 8월'
# '부당한 일요등교 지시'
# '아랍계 국가국국'
# ''
# '1969년'
# '3-3 무승부'
# '공개 프록시'
# ''
# '뷔르츠부르크 대학교'
# '순치제'
# '인체의 치수(인체측정학의 측정 기준)'
# '앙리 블랑슈'
# '근원 마그마가 형성되는 기작 기 '
# ''
# '남쪽'
# '64 군'
# '공병우 자판'
# '수리물리학'
# '1945년'
# "'청구의 원인'"
# '빛'
# '모터크로스 레이서'
# '사츠키'
# '아드레날린'
# ' 미'
# '1934년'
# ' '
# '베다는'
# '뉴질랜드'
# '구와바라'
# '대통령 캘빈 쿨리지'
# '개성'
# '제노바 공화국'
# ''
# '임'
# '을제 하'
# '옥시전 디스트로이어'
# '오삼계'
# '아스파르트산'
# '상대적 손실 가치'
# '블루 라인'
# '가압 카트리지'
# '미하일린'
# '1946년'
# '김정은'
# '가덕도'
# '언더우드 박사'
# '중동 건설 현장'
# '해련스님'
# '야기옐론 대학'
# '전달판'
# '레기온'
# '요한'
# '구금'
# '세르비아 왕국'
# '밀양 농잠학교'
# '무신'
# '마이클 뉴먼'
# '스카버러 타운 센터'
# '의사결정권자'
# '1949년'
# '와히드 박사'
# '화이트워터 사건'
# ' 스 '
# '동탁의 군대'
# ''
# '1970년'
# '3미터'
# '연극배우'
# '벤민 바커'
# '탈당'
# '5월 29일'
# '뇌 일부'
# 'OekakiBBS'
# '소루트비히'
# ''
# '교황 율리오 2세'
# ' '
# ''
# '안티오쿠스'
# '좀비'
# '인질이 된 다케치요(이에야스)의 양육을 위해'
# '1947년'
# ''
# '실루엣'
# '실학자'
# '모술'
# '에스토니아 인민전선의 창립위원으로서 라트비아와 리투아니아 인민전선과 협력하였다.'
# '키홀더'
# ' 의'
# '밀로셰비치'
# '보리스 타디치'
# '1994년'
# '1977년'
# '공훈의 보상'
# '중앙위원회'
# '"이탈리아 요리"'
# '일본'
# '연방 정부'
# '현무암 화방벽'
# '선'
# '피렌체'
# '1726년'
# '"명련사"'
# '조선혁명간부학교'
# '직선기선'
# ''
# '레드훅 스튜디오'
# '1924년'
# '카르멜 수녀원'
# '러시아 제국'
# '소방방재센터'
# '1967년'
# '존 벨링햄'
# '리틀 미스 루미에르 인터내셔널 월드대회'
# '조선무선공학원'
# "'나는 참된 보통 선거를 원한다'"
# '스'
# '안티오코스 3세'
# '세 가지'
# '비올라'
# ''
# '급소'
# "'Beetles(딱정벌레)'"
# ' 한 '
# '대밭골'
# '조조'
# ''
# ''
# ''
# '이'
# '아유미'
# '공화당원 투표인들 만을 화나게'
# '어사대부'
# '빌트루디스'
# '제8조'
# '석재'
# '관찰사'
# '석가모니'
# '프리드리히 니체'
# '뉴욕타임스'
# '1967년'
# '재단 X'
# '자유당 사'
# '서스펜디드 게임'
# '주노 해변\\n\\n주노 해변'
# '수수께끼의 콘드률'

# %%
with open("/opt/ml/mrc-level2-nlp-07/code/outputs/mixing_bowl/result.json",'w') as make_file:
    json.dump(json_data1,make_file,indent="\t",ensure_ascii=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-c36aa3352a51> in <module>
#       2 b = "12323"
#       3 p = re.compile(a)
# ----> 4 m = re.match(r(p),b)
#       5 m
#
# NameError: name 'r' is not defined
